# %%
import pandas as pd
import os
from datetime import datetime


customers_data = [
    {'customer_id': 'C001', 'name': 'Alice Smith', 'email': 'alice@example.com'},
    {'customer_id': 'C002', 'name': 'Bob Jones', 'email': 'bob@example.com'}
]

products_data = [
    {'product_id': 'P100', 'product_name': 'Laptop', 'price': 1200.00},
    {'product_id': 'P101', 'product_name': 'Mouse', 'price': 25.50},
    {'product_id': 'P102', 'product_name': 'Monitor', 'price': 300.00}
]

orders_data = [
    {'order_id': 'O-1', 'customer_id': 'C001', 'order_date': '2023-10-01', 'order_status': 'Completed'},
    {'order_id': 'O-2', 'customer_id': 'C002', 'order_date': '2023-10-05', 'order_status': 'Processing'}
]


order_items_data = [
    {'item_id': 'I-001', 'order_id': 'O-1', 'product_id': 'P100', 'quantity': 1, 'item_status': 'Delivered'},
    {'item_id': 'I-002', 'order_id': 'O-1', 'product_id': 'P101', 'quantity': 2, 'item_status': 'Delivered'},
    {'item_id': 'I-003', 'order_id': 'O-2', 'product_id': 'P102', 'quantity': 2, 'item_status': 'Shipped'},
    {'item_id': 'I-004', 'order_id': 'O-2', 'product_id': 'P101', 'quantity': 1, 'item_status': 'Pending'}
]


df_customers = pd.DataFrame(customers_data)
df_products = pd.DataFrame(products_data)
df_orders = pd.DataFrame(orders_data)
df_order_items = pd.DataFrame(order_items_data)
